# %% [markdown]
# Problem statement:
#
# -To predict the attrition

# %%
#loading the dataset

import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\Yash Bhardwaj\Downloads\ibm-hr-analytics-employee-attrition-performance\WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.sample(4)
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 635    35        No  Travel_Rarely        607  Research & Development
# 925    42        No  Travel_Rarely        603  Research & Development
# 950    31        No     Non-Travel        587                   Sales
# 1190   32        No  Travel_Rarely        977  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 635                  9          3  Life Sciences              1
# 925                  7          4        Medical              1
# 950                  2          4  Life Sciences              1
# 1190                 2          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 635              880  ...                         2            80
# 925             1292  ...                         4            80
# 950             1324  ...                         1            80
# ...

# %%
#checking for null values

df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# - so null values aren't present in the dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#checking the datatypes

df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# - most of the feature columns is of integer datatype but some has categorical or objective datatype, which needs to be transformed

# %%
#forming a list for categorical datatype features

categorical=[]
for i in df.columns:
    if df[i].dtypes=='object':
        categorical.append(i)
    else:
        pass

# %%
categorical
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
#transforming the categorical datatype

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Attrition_New']=le.fit_transform(df['Attrition'])
df['BusinessTravel_New']=le.fit_transform(df['BusinessTravel'])
df['Department_New']=le.fit_transform(df['Department'])
df['EducationField_New']=le.fit_transform(df['EducationField'])
df['Gender_New']=le.fit_transform(df['Gender'])
df['JobRole_New']=le.fit_transform(df['JobRole'])
df['MaritalStatus_New']=le.fit_transform(df['MaritalStatus'])
df['Over18_New']=le.fit_transform(df['Over18'])
df['OverTime_New']=le.fit_transform(df['OverTime'])

# %% [markdown]
# # EDA:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
sns.scatterplot('Age','Attrition',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Attrition'>

# %% [markdown]
# - for No 'Attrition' data is uniformly distributed

# %%
sns.countplot(df['Attrition'])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# - it can bee seen that the data is highlky imbalanced

# %%
sns.countplot(df['BusinessTravel'],hue=df['Attrition'])
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %% [markdown]
# - travel rarely has the highest count but with attrition No in dominance

# %%
def scatter(x):
    sns.scatterplot(df[x],df['Attrition'])
    plt.show()
    
def count(y):
    sns.countplot(df[y],hue=df['Attrition'])
    plt.show()

# %%
scatter('DailyRate')

# %% [markdown]
# -  the data is uniformly distributed

# %%
count('Department')

# %% [markdown]
# - okay so Research and Development has the highest count following sales and Human Resources, it can be seen that R&D has the highest No attrition count as well

# %%
scatter('DistanceFromHome')

# %% [markdown]
# - the data is uniformly distributed

# %%
count('Education')

# %% [markdown]
# - most employees have education label 3 but it also has highest No attrition

# %%
count('EducationField')

# %% [markdown]
# - Life Sciences has the highest number of count

# %%
count('EmployeeCount')

# %%
scatter('EmployeeNumber')

# %%
count('EnvironmentSatisfaction')

# %% [markdown]
# - label 1 has the highest count following by 3 then 4 then 2

# %%
count('Gender')

# %% [markdown]
# - most of the employees are male

# %%
scatter('HourlyRate')

# %% [markdown]
# - the data is uniformly distributed

# %%
count('JobInvolvement')

# %% [markdown]
# - label 3 has the highest count

# %%
count('JobLevel')

# %% [markdown]
# - JobLevel 1 has the highest count while 4 has the least

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['JobRole'])
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %% [markdown]
# - Sales Executive has the highest count, following by Research Scientist and Laboratory Technician, while Research Director and Human Resources has the least

# %%
count('JobSatisfaction')

# %% [markdown]
# - most employees agree with label 3 but highest No attrition count is with label 4

# %%
count('MaritalStatus')

# %% [markdown]
# - Most employees are single but the status with most No attrition count is Married

# %%
scatter('MonthlyIncome')

# %% [markdown]
# - most employees with Yes attrition has income in range 1200 to 11000

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition_New', 'BusinessTravel_New',
#        'Department_New', 'EducationField_New', 'Gender_New', 'JobRole_New',
#        'MaritalStatus_New', 'Over18_New', 'OverTime_New'],
#       dtype='object')

# %%
scatter('MonthlyRate')

# %% [markdown]
# - the data is uniformly distributed

# %%
count('NumCompaniesWorked')

# %% [markdown]
# - okay so most of the employees have worked before in 1 company only and thus has the maximum No attrition

# %%
sns.countplot(df['Over18'])
# Out:
# <AxesSubplot:xlabel='Over18', ylabel='count'>

# %% [markdown]
# - everyone is above 18

# %%
count('OverTime')

# %% [markdown]
# - okay so most employees do overtime and it can be seen the rate of attrition is good with employees who do overtime

# %%
#plotting scatterplot forr the rest numerical data

numerical1=['PercentSalaryHike','TotalWorkingYears','YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion','YearsWithCurrManager']

for i in numerical1:
    sns.scatterplot(i,'Attrition',data=df)
    plt.show()

# %% [markdown]
# Observations:
# - PerecentSalaryHike has the uniformly distributed data for both the Attrition classes
# - for YearsInCurrentRole range 0-`10.0 has the uniformly distributed data for both the Attrition classes
# - YearsWithCurrManager has uniformly distributed data in range 0-11.0

# %%
#plotting countplot for rest of the object datatype variables

numerical2=['PerformanceRating','RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel','TrainingTimesLastYear', 'WorkLifeBalance']
for i in numerical2:
    sns.countplot(df[i],hue=df['Attrition'])
    plt.show()

# %% [markdown]
# Observations:
# - PerformanceRating label 3 has the highest count
# - RelationshipSatisfaction label 3 and 4 has the highest count
# - StockOptionLevel 0 has maximum count but level 1 has the highest No attrition
# - TrainingTimeLastYear label 2 has the highest count following by 3
# - WorlLoifeBalance label 3 has the highest count

# %%
#checking for correlation

df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
plt.figure(figsize=(50,40))
sns.heatmap(df.corr(),annot=True,fmt='.1%',cmap='RdYlBu',linewidth=2) 
plt.show()

# %%
df.corr()['Attrition_New'].sort_values()
# Out:
# TotalWorkingYears          -0.171063
# JobLevel                   -0.169105
# YearsInCurrentRole         -0.160545
# MonthlyIncome              -0.159840
# Age                        -0.159205
# YearsWithCurrManager       -0.156199
# StockOptionLevel           -0.137145
# YearsAtCompany             -0.134392
# JobInvolvement             -0.130016
# JobSatisfaction            -0.103481
# EnvironmentSatisfaction    -0.103369
# WorkLifeBalance            -0.063939
# TrainingTimesLastYear      -0.059478
# DailyRate                  -0.056652
# RelationshipSatisfaction   -0.045872
# YearsSinceLastPromotion    -0.033019
# Education                  -0.031373
# PercentSalaryHike          -0.013478
# EmployeeNumber             -0.010577
# HourlyRate                 -0.006846
# BusinessTravel_New          0.000074
# PerformanceRating           0.002889
# MonthlyRate                 0.015170
# EducationField_New          0.026846
# Gender_New                  0.029453
# ...

# %% [markdown]
# Conclusion:
# - OverTime has the strongest correlation bond with the target variable following by MaritalStatus
# - DistanceFromHome, JobRole, Department, NumCompaniesWorked Gender, EducationField, MonthlyRate, PerfomanceRating, BussinessTravel has weak positive correlation bond with the target variable
# - TotalWorkingYears,JobLevel,YearsInCurrentRole,MonthlyIncome,Age,YearsWithCurrManager,StockOptionLevel,YearsAtCompany,JobInvolvement,JobSatisfaction,EnvironmentSatisfaction have good negative correlation bond
# - WorkLifeBalance,TrainingTimesLastYear,DailyRate,RelationshipSatisfaction,YearsSinceLastPromotion,Education,PercentSalaryHike,EmployeeNumber,HourlyRate has very weak negative correlation bond

# %%
#describing the dataset

df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Observations:
# - for all the variable features there isn't much difference present between mean and their median value, so less skewness might be present
# - standard deviation for features DailyRate,EmployeeNumber is high meaning, range of the data is high
# - difference between 75th percentile and maximum value is high for some feature variables so outliers might be present too

# %%
#let's check for outliers

sns.boxplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(df['DailyRate'])
# Out:
# <AxesSubplot:xlabel='DailyRate'>

# %%
sns.boxplot(df['EmployeeNumber'])
# Out:
# <AxesSubplot:xlabel='EmployeeNumber'>

# %%
sns.boxplot(df['HourlyRate'])
# Out:
# <AxesSubplot:xlabel='HourlyRate'>

# %% [markdown]
# - okay so now let's check outliers with zscore method

# %% [markdown]
# # Data Cleaning:
# - in this section we will deal with outliers,skewness, weak correlation etc.

# %%
#removing categorical feature variables

df.drop(categorical,axis=1,inplace=True)

# %%
print(df['EmployeeCount'].value_counts())
print(df['StandardHours'].value_counts())
print(df['Over18_New'].value_counts())
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64
# 80    1470
# Name: StandardHours, dtype: int64
# 0    1470
# Name: Over18_New, dtype: int64

# %%
#so these feature variables have only one type of class which is same for all the employees, so it won't be very useful for our model
df.drop(['EmployeeCount','StandardHours','Over18_New'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1470, 32)

# %%
#let's try zscore method for outliers removal

from scipy.stats import zscore

z=np.abs(zscore(df))
np.where(z>3)
# Out:
# (array([  28,   45,   62,   62,   63,   64,   85,   98,   98,  110,  123,
#          123,  123,  126,  126,  126,  153,  178,  187,  187,  190,  190,
#          218,  231,  231,  237,  237,  270,  270,  281,  326,  386,  386,
#          401,  411,  425,  425,  427,  445,  466,  473,  477,  535,  561,
#          561,  584,  592,  595,  595,  595,  616,  624,  635,  653,  653,
#          677,  686,  701,  716,  746,  749,  752,  799,  838,  861,  861,
#          875,  875,  894,  914,  914,  918,  922,  926,  926,  937,  956,
#          962,  976,  976, 1008, 1024, 1043, 1078, 1078, 1086, 1086, 1093,
#         1111, 1116, 1116, 1135, 1138, 1138, 1156, 1184, 1221, 1223, 1242,
#         1295, 1301, 1301, 1303, 1327, 1331, 1348, 1351, 1401, 1414, 1430],
#        dtype=int64),
#  array([23, 22, 20, 22, 21, 22, 17, 17, 20, 22, 21, 22, 23, 17, 20, 22, 23,
#         22, 17, 23, 20, 21, 22, 21, 23, 20, 22, 17, 20, 21, 22, 22, 23, 17,
# ...

# %%
z.iloc[28][23]
# Out:
# 3.6100788863016295

# %%
#so only a few are present, so we will remove them or keep them, it won't affect our model majorily

df_new=df[(z<3).all(axis=1)]

# %%
df.shape
# Out:
# (1470, 32)

# %%
df_new.shape
# Out:
# (1387, 32)

# %%
print("Data loss:",(1470-1387)/1470*100,'%')
# Out:
# Data loss: 5.646258503401361 %

# %% [markdown]
# - so as the data loss is very less, we will use the dataset without outliers

# %%
df_new.corr()['Attrition_New'].sort_values()
# Out:
# TotalWorkingYears          -0.185619
# JobLevel                   -0.171968
# YearsInCurrentRole         -0.171015
# YearsAtCompany             -0.166455
# YearsWithCurrManager       -0.162297
# MonthlyIncome              -0.161848
# Age                        -0.159366
# StockOptionLevel           -0.136676
# JobInvolvement             -0.133957
# JobSatisfaction            -0.114206
# EnvironmentSatisfaction    -0.112393
# WorkLifeBalance            -0.062492
# TrainingTimesLastYear      -0.057285
# DailyRate                  -0.057220
# RelationshipSatisfaction   -0.052344
# Education                  -0.032703
# YearsSinceLastPromotion    -0.029263
# EmployeeNumber             -0.010169
# PercentSalaryHike          -0.006267
# HourlyRate                 -0.001532
# BusinessTravel_New         -0.001041
# PerformanceRating           0.010781
# MonthlyRate                 0.014888
# EducationField_New          0.023585
# Gender_New                  0.036252
# ...

# %%
#dropping the weakly correlated variables

df_new2=df_new.drop(['WorkLifeBalance','TrainingTimesLastYear','DailyRate','RelationshipSatisfaction','YearsSinceLastPromotion','Education','YearsSinceLastPromotion','EmployeeNumber','PercentSalaryHike','HourlyRate','BusinessTravel_New','PerformanceRating','MonthlyRate','EducationField_New','Gender_New','NumCompaniesWorked','Department_New','JobRole_New','DistanceFromHome'],axis=1)
df_new2.shape
# Out:
# (1387, 14)

# %%
# now selecting our feature and target variable for further process

x=df_new2.drop('Attrition_New',axis=1)
y=df_new2['Attrition_New']

# %%
x.shape
# Out:
# (1387, 13)

# %%
y.shape
# Out:
# (1387,)

# %%
#checking for skewness

x.skew()
# Out:
# Age                        0.472280
# EnvironmentSatisfaction   -0.325285
# JobInvolvement            -0.501401
# JobLevel                   1.126075
# JobSatisfaction           -0.345612
# MonthlyIncome              1.544770
# StockOptionLevel           0.962332
# TotalWorkingYears          1.034487
# YearsAtCompany             1.248623
# YearsInCurrentRole         0.726675
# YearsWithCurrManager       0.694506
# MaritalStatus_New         -0.160952
# OverTime_New               0.954751
# dtype: float64

# %% [markdown]
# threshold= +/- 0.50 , so most of the feature variables are falling out of this, we will perform data transformation technique

# %%
sns.distplot(df['JobLevel'])
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='Density'>

# %%
sns.distplot(df['TotalWorkingYears'])
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Density'>

# %%
sns.distplot(df['YearsAtCompany'])
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Density'>

# %% [markdown]
# - so it can be seen that skewness is present

# %%
#data transformation for less skewness

from sklearn.preprocessing import power_transform

x=power_transform(x,method='yeo-johnson')

# %%
x=pd.DataFrame(x)
x.skew()
# Out:
# 0    -0.004079
# 1    -0.205472
# 2    -0.018801
# 3     0.110769
# 4    -0.217730
# 5     0.027700
# 6     0.089929
# 7    -0.009666
# 8    -0.025230
# 9    -0.069631
# 10   -0.070570
# 11   -0.158253
# 12    0.954751
# dtype: float64

# %% [markdown]
# - so skewness has been reduced

# %%
sns.distplot(df['JobLevel'])
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='Density'>

# %%
sns.distplot(df['TotalWorkingYears'])
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Density'>

# %%
sns.distplot(df['YearsAtCompany'])
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Density'>

# %%
#checking for multicollinearity

from statsmodels.stats.outliers_influence import variance_inflation_factor

def vif_calc():
    vif=pd.DataFrame()
    vif['VIF Factor']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif['features']=x.columns
    print(vif)

# %%
vif_calc()
# Out:
#     VIF Factor  features
# 0     1.852606         0
# 1     1.011140         1
# 2     1.009221         2
# 3     5.577803         3
# 4     1.006549         4
# 5     5.777242         5
# 6     2.242884         6
# 7     3.558057         7
# 8     5.782831         8
# 9     3.376444         9
# 10    3.383218        10
# 11    2.252807        11
# 12    1.008828        12

# %% [markdown]
# - okay so only three features have vif above 5 that too not so much, multicollinearity isn't very strong between features

# %%
#now

y.value_counts()
# Out:
# 0    1158
# 1     229
# Name: Attrition_New, dtype: int64

# %% [markdown]
# - it can be seen that the data is highly imbalanced, so we will use over sampling method

# %%
from imblearn.over_sampling import SMOTE

smt=SMOTE()

train_x,train_y=smt.fit_resample(x,y)

# %%
train_x.shape
# Out:
# (2316, 13)

# %%
train_y.shape
# Out:
# (2316,)

# %%
train_y.value_counts()
# Out:
# 1    1158
# 0    1158
# Name: Attrition_New, dtype: int64

# %% [markdown]
# - okay so data is balanced now

# %% [raw]
# As the target variable has two type of class only this is a binary classification problem:

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lr=LogisticRegression()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(train_x,train_y,random_state=i,test_size=.30)
    lr.fit(x_train,y_train)
    predtrain=lr.predict(x_train)
    predlr=lr.predict(x_test)
    if round(accuracy_score(y_test,predlr)*100)==round(accuracy_score(y_train,predtrain)*100):
        print('At random state',i,'the model performs very well')
        print('At random state',i,':')
        print('Training accuracy score is',accuracy_score(y_train,predtrain)*100)
        print('Testing accuracy score is',accuracy_score(y_test,predlr)*100,'\n')
# Out:
# At random state 9 the model performs very well
# At random state 9 :
# Training accuracy score is 73.53485502776064
# Testing accuracy score is 74.10071942446042
#
# At random state 12 the model performs very well
# At random state 12 :
# Training accuracy score is 74.58359037631091
# Testing accuracy score is 75.39568345323741
#
# At random state 19 the model performs very well
# At random state 19 :
# Training accuracy score is 75.01542257865516
# Testing accuracy score is 75.39568345323741
#
# At random state 29 the model performs very well
# At random state 29 :
# Training accuracy score is 74.89204194941395
# Testing accuracy score is 74.53237410071942
#
# At random state 32 the model performs very well
# At random state 32 :
# Training accuracy score is 74.76866132017274
# Testing accuracy score is 74.53237410071942
#
# At random state 36 the model performs very well
# At random state 36 :
# Training accuracy score is 74.89204194941395
# ...

# %%
#so we will use random state as 19 for further process

x_train,x_test,y_train,y_test=train_test_split(train_x,train_y,random_state=19,test_size=.30)
lr.fit(x_train,y_train)
predtrain=lr.predict(x_train)
predlr=lr.predict(x_test)

# %%
print(accuracy_score(y_test,predlr)*100)
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# 75.39568345323741
# [[258  92]
#  [ 79 266]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.75       350
#            1       0.74      0.77      0.76       345
#
#     accuracy                           0.75       695
#    macro avg       0.75      0.75      0.75       695
# weighted avg       0.75      0.75      0.75       695

# %%
from sklearn.metrics import mean_squared_error

mselr=mean_squared_error(y_test,predlr)

print(mselr)
# Out:
# 0.2460431654676259

# %%
#checking cross validation score for logistic regression

for j in range(2,10):
    lrs=cross_val_score(lr,train_x,train_y,cv=j)
    lrc=lrs.mean()
    print('At cv=',j)
    print('Cross Validation Score is:',lrc*100)
    print('Accuracy score is:',accuracy_score(y_test,predlr)*100,'\n')
# Out:
# At cv= 2
# Cross Validation Score is: 74.3091537132988
# Accuracy score is: 75.39568345323741
#
# At cv= 3
# Cross Validation Score is: 74.61139896373057
# Accuracy score is: 75.39568345323741
#
# At cv= 4
# Cross Validation Score is: 74.56822107081175
# Accuracy score is: 75.39568345323741
#
# At cv= 5
# Cross Validation Score is: 74.56831384523721
# Accuracy score is: 75.39568345323741
#
# At cv= 6
# Cross Validation Score is: 74.69775474956822
# Accuracy score is: 75.39568345323741
#
# At cv= 7
# Cross Validation Score is: 74.99980382155609
# Accuracy score is: 75.39568345323741
#
# At cv= 8
# Cross Validation Score is: 74.39506025533946
# Accuracy score is: 75.39568345323741
#
# At cv= 9
# Cross Validation Score is: 74.52350549807794
# Accuracy score is: 75.39568345323741

# %% [markdown]
# - as cross validation score coming out to be very close to accuracy score the model is working fine

# %%
#roc auc plotting for logisticRegression

from sklearn.metrics import roc_curve,auc

fpr,tpr,thresholds=roc_curve(y_test,predlr)

roc_auc=auc(fpr,tpr)

plt.figure()
plt.plot(fpr,tpr,color='darkorange',lw=10,label='ROC curve (area=%.2f)'%roc_auc)
plt.plot([0,1],[0,1],color='navy',lw=10,linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('False Positive rate')
plt.ylabel('True Positive rate')
plt.title('Receiver Operating Characteristics')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# - so our model is working well than the base model

# %%
#lets try some more classifcation algorithms 

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

knn=KNeighborsClassifier()

x_train,x_test,y_train,y_test=train_test_split(train_x,train_y,random_state=19,test_size=.30)
knn.fit(x_train,y_train)
predtrain=knn.predict(x_train)
predknn=knn.predict(x_test)

print(accuracy_score(y_test,predknn)*100)
# Out:
# 84.17266187050359

# %%
print(accuracy_score(y_test,predknn)*100)
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 84.17266187050359
# [[244 106]
#  [  4 341]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.70      0.82       350
#            1       0.76      0.99      0.86       345
#
#     accuracy                           0.84       695
#    macro avg       0.87      0.84      0.84       695
# weighted avg       0.87      0.84      0.84       695

# %%
mseknn=mean_squared_error(y_test,predknn)

print(mseknn)
# Out:
# 0.15827338129496402

# %%
#checking cross validation score for KNeighbors

for j in range(2,10):
    knns=cross_val_score(knn,train_x,train_y,cv=j)
    knnc=knns.mean()
    print('At cv=',j)
    print('Cross Validation Score is:',knnc*100)
    print('Accuracy score is:',accuracy_score(y_test,predknn)*100,'\n')
# Out:
# At cv= 2
# Cross Validation Score is: 82.68566493955095
# Accuracy score is: 84.17266187050359
#
# At cv= 3
# Cross Validation Score is: 84.02417962003454
# Accuracy score is: 84.17266187050359
#
# At cv= 4
# Cross Validation Score is: 84.67184801381693
# Accuracy score is: 84.17266187050359
#
# At cv= 5
# Cross Validation Score is: 84.8886571832874
# Accuracy score is: 84.17266187050359
#
# At cv= 6
# Cross Validation Score is: 84.84455958549223
# Accuracy score is: 84.17266187050359
#
# At cv= 7
# Cross Validation Score is: 85.01719831024968
# Accuracy score is: 84.17266187050359
#
# At cv= 8
# Cross Validation Score is: 85.01953824126
# Accuracy score is: 84.17266187050359
#
# At cv= 9
# Cross Validation Score is: 85.19155296822476
# Accuracy score is: 84.17266187050359

# %% [markdown]
# - so KNeighbors is giving high accuracy with high cross validation

# %%
#decisonTree

dtc=DecisionTreeClassifier()
x_train,x_test,y_train,y_test=train_test_split(train_x,train_y,random_state=19,test_size=.30)
dtc.fit(x_train,y_train)
predtrain=dtc.predict(x_train)
preddtc=dtc.predict(x_test)

print(accuracy_score(y_test,preddtc)*100)
# Out:
# 85.03597122302158

# %%
print(accuracy_score(y_test,preddtc)*100)
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 85.03597122302158
# [[291  59]
#  [ 45 300]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       350
#            1       0.84      0.87      0.85       345
#
#     accuracy                           0.85       695
#    macro avg       0.85      0.85      0.85       695
# weighted avg       0.85      0.85      0.85       695

# %%
msedtc=mean_squared_error(y_test,preddtc)

print(msedtc)
# Out:
# 0.14964028776978416

# %%
#checking cross validation score for DecsionTree

for j in range(2,10):
    dtcs=cross_val_score(dtc,train_x,train_y,cv=j)
    dtcc=dtcs.mean()
    print('At cv=',j)
    print('Cross Validation Score is:',dtcc*100)
    print('Accuracy score is:',accuracy_score(y_test,preddtc)*100,'\n')
# Out:
# At cv= 2
# Cross Validation Score is: 84.6286701208981
# Accuracy score is: 85.03597122302158
#
# At cv= 3
# Cross Validation Score is: 85.01727115716754
# Accuracy score is: 85.03597122302158
#
# At cv= 4
# Cross Validation Score is: 85.9671848013817
# Accuracy score is: 85.03597122302158
#
# At cv= 5
# Cross Validation Score is: 85.97192224622029
# Accuracy score is: 85.03597122302158
#
# At cv= 6
# Cross Validation Score is: 86.26943005181347
# Accuracy score is: 85.03597122302158
#
# At cv= 7
# Cross Validation Score is: 86.31446096702895
# Accuracy score is: 85.03597122302158
#
# At cv= 8
# Cross Validation Score is: 87.00692041522493
# Accuracy score is: 85.03597122302158
#
# At cv= 9
# Cross Validation Score is: 86.79422341534368
# Accuracy score is: 85.03597122302158

# %% [markdown]
# - upto now DecisionTreeClassifier is giving us the best results

# %%
#now, let's try some ensemble techniques:

from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier

# %%
#RandomForestClassifier

rf=RandomForestClassifier()
x_train,x_test,y_train,y_test=train_test_split(train_x,train_y,random_state=19,test_size=.30)
rf.fit(x_train,y_train)
predtrain=rf.predict(x_train)
predrf=rf.predict(x_test)

print(accuracy_score(y_test,predrf)*100)
# Out:
# 91.79856115107914

# %%
print(accuracy_score(y_test,predrf)*100)
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))

# %%
mserf=mean_squared_error(y_test,predrf)

print(mserf)
# Out:
# 0.08201438848920864

# %%
#checking cross validation score for RandomForest

for j in range(2,10):
    rfs=cross_val_score(rf,train_x,train_y,cv=j)
    rfc=rfs.mean()
    print('At cv=',j)
    print('Cross Validation Score is:',rfc*100)
    print('Accuracy score is:',accuracy_score(y_test,predrf)*100,'\n')
# Out:
# At cv= 2
# Cross Validation Score is: 91.27806563039724
# Accuracy score is: 91.79856115107914
#
# At cv= 3
# Cross Validation Score is: 92.05526770293609
# Accuracy score is: 91.79856115107914
#
# At cv= 4
# Cross Validation Score is: 92.573402417962
# Accuracy score is: 91.79856115107914
#
# At cv= 5
# Cross Validation Score is: 93.35490057347137
# Accuracy score is: 91.79856115107914
#
# At cv= 6
# Cross Validation Score is: 92.53022452504317
# Accuracy score is: 91.79856115107914
#
# At cv= 7
# Cross Validation Score is: 92.66201069826448
# Accuracy score is: 91.79856115107914
#
# At cv= 8
# Cross Validation Score is: 92.88077198425009
# Accuracy score is: 91.79856115107914
#
# At cv= 9
# Cross Validation Score is: 92.70972628587324
# Accuracy score is: 91.79856115107914

# %% [markdown]
# - So it can be seen that with randomforest our model is working extremely well

# %%
#AdaBoostClassifier

ada=AdaBoostClassifier()
x_train,x_test,y_train,y_test=train_test_split(train_x,train_y,random_state=19,test_size=.30)
ada.fit(x_train,y_train)
predtrain=ada.predict(x_train)
predada=ada.predict(x_test)

print(accuracy_score(y_test,predada)*100)
# Out:
# 86.47482014388488

# %%
print(accuracy_score(y_test,predada)*100)
print(confusion_matrix(y_test,predada))
print(classification_report(y_test,predada))
# Out:
# 86.47482014388488
# [[297  53]
#  [ 41 304]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86       350
#            1       0.85      0.88      0.87       345
#
#     accuracy                           0.86       695
#    macro avg       0.87      0.86      0.86       695
# weighted avg       0.87      0.86      0.86       695

# %%
mseada=mean_squared_error(y_test,predada)

print(mseada)
# Out:
# 0.13525179856115108

# %%
#checking cross validation score for AdaBoost

for j in range(2,10):
    adas=cross_val_score(ada,train_x,train_y,cv=j)
    adac=adas.mean()
    print('At cv=',j)
    print('Cross Validation Score is:',adac*100)
    print('Accuracy score is:',accuracy_score(y_test,predada)*100,'\n')
# Out:
# At cv= 2
# Cross Validation Score is: 85.146804835924
# Accuracy score is: 86.47482014388488
#
# At cv= 3
# Cross Validation Score is: 83.7651122625216
# Accuracy score is: 86.47482014388488
#
# At cv= 4
# Cross Validation Score is: 84.88773747841105
# Accuracy score is: 86.47482014388488
#
# At cv= 5
# Cross Validation Score is: 85.41297385864303
# Accuracy score is: 86.47482014388488
#
# At cv= 6
# Cross Validation Score is: 85.88082901554405
# Accuracy score is: 86.47482014388488
#
# At cv= 7
# Cross Validation Score is: 87.30738546448517
# Accuracy score is: 86.47482014388488
#
# At cv= 8
# Cross Validation Score is: 86.5339756592292
# Accuracy score is: 86.47482014388488
#
# At cv= 9
# Cross Validation Score is: 85.93172395995671
# Accuracy score is: 86.47482014388488

# %%
#GradientBoostingClassifier

gb=GradientBoostingClassifier()
x_train,x_test,y_train,y_test=train_test_split(train_x,train_y,random_state=19,test_size=.30)
gb.fit(x_train,y_train)
predtrain=gb.predict(x_train)
predgb=gb.predict(x_test)

print(accuracy_score(y_test,predgb)*100)
# Out:
# 90.50359712230215

# %%
print(accuracy_score(y_test,predgb)*100)
print(confusion_matrix(y_test,predgb))
print(classification_report(y_test,predgb))
# Out:
# 90.50359712230215
# [[323  27]
#  [ 39 306]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91       350
#            1       0.92      0.89      0.90       345
#
#     accuracy                           0.91       695
#    macro avg       0.91      0.90      0.90       695
# weighted avg       0.91      0.91      0.90       695

# %%
msegb=mean_squared_error(y_test,predgb)

print(msegb)
# Out:
# 0.09496402877697842

# %%
#checking cross validation score for GradientBoosting

for j in range(2,10):
    gbs=cross_val_score(gb,train_x,train_y,cv=j)
    gbc=gbs.mean()
    print('At cv=',j)
    print('Cross Validation Score is:',gbc*100)
    print('Accuracy score is:',accuracy_score(y_test,predgb)*100,'\n')
# Out:
# At cv= 2
# Cross Validation Score is: 87.9965457685665
# Accuracy score is: 90.50359712230215
#
# At cv= 3
# Cross Validation Score is: 87.56476683937824
# Accuracy score is: 90.50359712230215
#
# At cv= 4
# Cross Validation Score is: 88.3419689119171
# Accuracy score is: 90.50359712230215
#
# At cv= 5
# Cross Validation Score is: 88.48169732628286
# Accuracy score is: 90.50359712230215
#
# At cv= 6
# Cross Validation Score is: 89.42141623488773
# Accuracy score is: 90.50359712230215
#
# At cv= 7
# Cross Validation Score is: 89.38099161664118
# Accuracy score is: 90.50359712230215
#
# At cv= 8
# Cross Validation Score is: 89.60297100584656
# Accuracy score is: 90.50359712230215
#
# At cv= 9
# Cross Validation Score is: 89.82076366475967
# Accuracy score is: 90.50359712230215

# %%
from sklearn.metrics import accuracy_score as acs

algodf=pd.DataFrame({'Mean Squared Error':[mselr,mseknn,msedtc,mserf,mseada,msegb],'Accuracy Score':[acs(y_test,predlr),acs(y_test,predknn),acs(y_test,preddtc),acs(y_test,predrf),acs(y_test,predada),acs(y_test,predgb)],'Cross Validation':[lrc,knnc,dtcc,rfc,adac,gbc]},index=['Logistic','KNeighbors','DecisionTree','RandomForest','AdaBoost','GradientBoosting'])
algodf
# Out:
#                   Mean Squared Error  Accuracy Score  Cross Validation
# Logistic                    0.246043        0.753957          0.745235
# KNeighbors                  0.158273        0.841727          0.851916
# DecisionTree                0.149640        0.850360          0.867942
# RandomForest                0.082014        0.917986          0.927097
# AdaBoost                    0.135252        0.864748          0.859317
# GradientBoosting            0.094964        0.905036          0.898208

# %% [markdown]
# - so it can be seen that RandomForestClassifier is giving us the best results

# %%
#doing hyperparametertuning on RandomForest for best results

from sklearn.model_selection import GridSearchCV

rf=RandomForestClassifier()
parameters={'criterion':["gini", "entropy"],'max_features':['sqrt','log2','auto']}
clf=GridSearchCV(rf,parameters)
x_train,x_test,y_train,y_test=train_test_split(train_x,train_y,random_state=19,test_size=.30)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'entropy', 'max_features': 'auto'}

# %%
rf=RandomForestClassifier(criterion='entropy', max_features= 'auto')
for i in range(100):
    x_train,x_test,y_train,y_test=train_test_split(train_x,train_y,random_state=i,test_size=.30)
    rf.fit(x_train,y_train)
    predtrain=rf.predict(x_train)
    predrf=rf.predict(x_test)
    if round(accuracy_score(y_test,predrf)*100)==93:
        print('At random state',i,'the model performs very well')
        print('Testing accuracy score is',accuracy_score(y_test,predrf)*100,'\n')
# Out:
# At random state 2 the model performs very well
# Testing accuracy score is 92.5179856115108
#
# At random state 9 the model performs very well
# Testing accuracy score is 93.09352517985612
#
# At random state 10 the model performs very well
# Testing accuracy score is 92.66187050359711
#
# At random state 15 the model performs very well
# Testing accuracy score is 92.66187050359711
#
# At random state 21 the model performs very well
# Testing accuracy score is 92.5179856115108
#
# At random state 28 the model performs very well
# Testing accuracy score is 93.09352517985612
#
# At random state 36 the model performs very well
# Testing accuracy score is 92.5179856115108
#
# At random state 40 the model performs very well
# Testing accuracy score is 93.38129496402877
#
# At random state 45 the model performs very well
# Testing accuracy score is 92.5179856115108
#
# At random state 53 the model performs very well
# Testing accuracy score is 92.66187050359711
#
# ...

# %%
rf=RandomForestClassifier(criterion='entropy', max_features= 'auto')
x_train,x_test,y_train,y_test=train_test_split(train_x,train_y,random_state=28,test_size=.30)
rf.fit(x_train,y_train)
predtrain=rf.predict(x_train)
predrf=rf.predict(x_test)

# %%
#checking cross validation score for RandomForest

rf=RandomForestClassifier(criterion='entropy', max_features= 'auto')
for j in range(2,10):
    rfs=cross_val_score(rf,train_x,train_y,cv=j)
    rfc=rfs.mean()
    print('At cv=',j)
    print('Cross Validation Score is:',rfc*100,'\n')
# Out:
# At cv= 2
# Cross Validation Score is: 91.32124352331607
#
# At cv= 3
# Cross Validation Score is: 92.01208981001727
#
# At cv= 4
# Cross Validation Score is: 92.96200345423142
#
# At cv= 5
# Cross Validation Score is: 92.75052133760333
#
# At cv= 6
# Cross Validation Score is: 92.4006908462867
#
# At cv= 7
# Cross Validation Score is: 92.40279358104131
#
# At cv= 8
# Cross Validation Score is: 93.01008232907768
#
# At cv= 9
# Cross Validation Score is: 92.84043341142245

# %%
print(classification_report(y_test,predrf))
print(confusion_matrix(y_test,predrf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       347
#            1       0.92      0.94      0.93       348
#
#     accuracy                           0.93       695
#    macro avg       0.93      0.93      0.93       695
# weighted avg       0.93      0.93      0.93       695
#
# [[318  29]
#  [ 21 327]]

# %% [markdown]
# - the recall is excellent, precision as well

# %%
print('Mean Squared Error:',mean_squared_error(y_test,predrf))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,predrf)))
# Out:
# Mean Squared Error: 0.07194244604316546
# Root Mean Squared Error: 0.26822089039291

# %% [markdown]
# - the errors are so close to zero, the model is performing extremely well

# %%
#roc auc plotting


fpr,tpr,thresholds=roc_curve(y_test,predrf)

roc_auc=auc(fpr,tpr)

plt.figure()
plt.plot(fpr,tpr,color='darkorange',lw=10,label='ROC curve (area=%.2f)'%roc_auc)
plt.plot([0,1],[0,1],color='navy',lw=10,linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('False Positive rate')
plt.ylabel('True Positive rate')
plt.title('Receiver Operating Characteristics')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# - The area under RF model is much larger than base model, the more the area the better the model

# %%
print('The model is performing extremely well with RandomForestClassifier')
print('Accuracy:',round(accuracy_score(y_test,predrf)*100))
print('Cross Validation Score:',round(rfc*100))
# Out:
# The model is performing extremely well with RandomForestClassifier
# Accuracy: 93
# Cross Validation Score: 93

# %%
preddf=pd.DataFrame({'Original Attrition':y_test,'Predicted Attrition':predrf})
preddf
# Out:
#       Original Attrition  Predicted Attrition
# 1891                   1                    1
# 14                     1                    1
# 1895                   1                    1
# 971                    1                    0
# 2073                   1                    1
# ...                  ...                  ...
# 24                     1                    1
# 1854                   1                    0
# 1066                   0                    0
# 1649                   1                    1
# 330                    0                    1
#
# [695 rows x 2 columns]

# %%
#saving the model

import pickle

pickle.dump(rf,open('attrition.pkl','wb'))
